# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/KIIT/Desktop/devanshilist")
sns.boxplot(x="Name",y="HP",data=df)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("C:/Users/KIIT/Desktop/devanshilist",encoding='latin-1')
data.head(10) 
data['#'].count()
sns.catplot(
    x='Generation', 
    data=data,
    height=5,
    aspect=1.2,
    kind='count'
).set_axis_labels('Generation', '# of Pokemon')

plt.show()

# %%
for index, row in data.iterrows():
    for ind,r in data.iterrows():
        if row['Total'] > r['Total']:
            if row['Generation'] == 4 and r['Legendary']==True :
                    print(index," ",row['Name'],"-",row['Total'],"     ",r['Name'],"-",r['Total'])
# Out:
# 493   Garchomp - 600       Articuno - 580
# 493   Garchomp - 600       Zapdos - 580
# 493   Garchomp - 600       Moltres - 580
# 493   Garchomp - 600       Raikou - 580
# 493   Garchomp - 600       Entei - 580
# 493   Garchomp - 600       Suicune - 580
# 493   Garchomp - 600       Regirock - 580
# 493   Garchomp - 600       Regice - 580
# 493   Garchomp - 600       Registeel - 580
# 493   Garchomp - 600       Uxie - 580
# 493   Garchomp - 600       Mesprit - 580
# 493   Garchomp - 600       Azelf - 580
# 493   Garchomp - 600       Cobalion - 580
# 493   Garchomp - 600       Terrakion - 580
# 493   Garchomp - 600       Virizion - 580
# 493   Garchomp - 600       TornadusIncarnate Forme - 580
# 493   Garchomp - 600       TornadusTherian Forme - 580
# 493   Garchomp - 600       ThundurusIncarnate Forme - 580
# 493   Garchomp - 600       ThundurusTherian Forme - 580
# 494   GarchompMega Garchomp - 700       Articuno - 580
# 494   GarchompMega Garchomp - 700       Zapdos - 580
# ...
